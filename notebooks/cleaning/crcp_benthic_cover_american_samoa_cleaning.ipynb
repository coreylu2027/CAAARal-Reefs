# %%
import os
import pandas as pd

# %%
curr_dir = os.getcwd()
par_dir = os.path.join(curr_dir, "..", "..")
par_dir_abs = os.path.abspath(par_dir)

df = pd.read_csv(par_dir_abs + "/data/raw/CORIS_DATA/PACIFIC/AMERICAN_SAMOA/CRCP_Benthic_Cover_American_Samoa_d45e_d417_3977.csv")

pd.set_option('display.max_columns', None)

dropped_cols = ['ROUNDID', 'MISSIONID', 'SITE', 'SITEVISITID', 'ISLAND', 'REEF_ZONE', 'SURVEY_TYPE', 'DEPTH_BIN', 'PERM_SITE', 'CLIMATE_STATION_YN', 'DATE_', 'IMAGE_NAME', 'Image_URL', 'OBS_YEAR', 'REPLICATE', 'PHOTOID', 'ANALYST', 'accession_url']

df = df.drop(columns = dropped_cols, axis=1)

df.to_csv('Benthic_Cover_American_Samoa_Cleaned.csv')
# Out:
# /var/folders/hl/s0xx7r0j66nf3d472gxnx2880000gn/T/ipykernel_79592/2103456434.py:5: DtypeWarning: Columns (1,2,10,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(par_dir_abs + "/data/raw/CORIS_DATA/PACIFIC/AMERICAN_SAMOA/CRCP_Benthic_Cover_American_Samoa_d45e_d417_3977.csv")
