# %%
import pandas as pd
import os

# %%
curr_dir = os.getcwd()
par_dir = os.path.join(curr_dir, "..", "..")
par_dir_abs = os.path.abspath(par_dir)

df = pd.read_csv(par_dir_abs + "/data/raw/CORIS_DATA/ATLANTIC/FLORIDA/CRCP_Reef_Fish_Surveys_Florida_e9ac_3abf_3b32.csv")

pd.set_option('display.max_columns', None)

dropped_cols = ['PRIMARY_SAMPLE_UNIT', 'YEAR', 'MONTH', 'DAY', 'Date_UTC', 'STATION_NR', 'DEPTH', 'MAPGRID_NR', 'ZONE_NR', 'RUGOSITY_CD', 'SUB_REGION_NR', 'SPECIES_NR', 'length_fish', 'NUM', 'TIME_SEEN', 'MPA_NR', 'PROT', 'STRAT', 'REGION', 'sample_year', 'accession_url']

df = df.drop(columns = dropped_cols, axis = 1)

df.to_csv('CRCP_Fish_Survey_Florida_Cleaned.csv')
# Out:
# /var/folders/hl/s0xx7r0j66nf3d472gxnx2880000gn/T/ipykernel_78637/3570660161.py:5: DtypeWarning: Columns (1,2,3,9,10,21,22,23,28,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(par_dir_abs + "/data/raw/CORIS_DATA/ATLANTIC/FLORIDA/CRCP_Reef_Fish_Surveys_Florida_e9ac_3abf_3b32.csv")
#                          time       latitude     longitude  \
# 0                         UTC  degrees_north  degrees_east
# 1        2021-07-10T00:00:00Z       24.64342     -83.09736
# 2        2021-07-10T00:00:00Z       24.64342     -83.09736
# 3        2021-07-10T00:00:00Z       24.64342     -83.09736
# 4        2021-07-10T00:00:00Z       24.64342     -83.09736
# ...                       ...            ...           ...
# 3255459  2018-08-31T00:00:00Z       25.51582     -80.10002
# 3255460  2018-08-31T00:00:00Z       25.51582     -80.10002
# 3255461  2018-08-31T00:00:00Z       25.51561     -80.10063
# ...
