# %%
import pandas as pd
import os

# %%
curr_dir = os.getcwd()
par_dir = os.path.join(curr_dir, "..", "..")
par_dir_abs = os.path.abspath(par_dir)

df = pd.read_csv(par_dir_abs + "/data/raw/CORIS_DATA/ATLANTIC/PUERTO_RICO/CRCP_Reef_Fish_Surveys_Puerto_Rico_98b1_72d4_d38b.csv")

pd.set_option('display.max_columns', None)

dropped_cols = ['YEAR', 'MONTH', 'DAY', 'Date_UTC', 'PRIMARY_SAMPLE_UNIT', 'STATION_NR', 'SAMPLE_DEPTH', 'UNDERWATER_VISIBILITY', 'MAPGRID_NR', 'DEPTH_STRAT', 'SUB_REGION_NAME', 'ADMIN', 'SUB_REGION_NAME_DESCRIPTION', 'Administration_Description', 'SPECIES_NR', 'PROT', 'STRAT_Description', 'accession_url']

df = df.drop(columns = dropped_cols, axis=1)

df.to_csv('CRCP_Fish_Survey_Puerto_Rico_Cleaned.csv')
# Out:
# /var/folders/hl/s0xx7r0j66nf3d472gxnx2880000gn/T/ipykernel_78866/2550774826.py:5: DtypeWarning: Columns (1,2,9,10,24,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(par_dir_abs + "/data/raw/CORIS_DATA/ATLANTIC/PUERTO_RICO/CRCP_Reef_Fish_Surveys_Puerto_Rico_98b1_72d4_d38b.csv")
#                         time       latitude     longitude HABITAT_CD  \
# 0                        UTC  degrees_north  degrees_east        NaN
# 1       2023-08-30T00:00:00Z       18.08047     -65.47185       PVMT
# 2       2023-08-30T00:00:00Z       18.08047     -65.47185       PVMT
# 3       2023-08-30T00:00:00Z       18.08047     -65.47185       PVMT
# 4       2023-08-30T00:00:00Z       18.08047     -65.47185       PVMT
# ...                      ...            ...           ...        ...
# 387633  2023-07-22T00:00:00Z       18.46642      -66.0666       AGRF
# 387634  2023-07-22T00:00:00Z       18.46642      -66.0666       AGRF
# ...
