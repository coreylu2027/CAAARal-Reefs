# %%
import pandas as pd
import os

# %%
curr_dir = os.getcwd()
par_dir = os.path.join(curr_dir, "..", "..")
par_dir_abs = os.path.abspath(par_dir)

df = pd.read_csv(par_dir_abs + "/data/raw/CORIS_DATA/ATLANTIC/USVI/CRCP_Coral_Demographic_Survey_USVI_a96f_e9c4_c0c5.csv")

pd.set_option('display.max_columns', None)

dropped_cols = ['REGION', 'REGION_DESCRIPTION', 'PRIMARY_SAMPLE_UNIT', 'STATION_NR', 'YEAR', 'MONTH', 'DAY', 'Date_UTC', 'HABITAT_CD', 'STRAT', 'RUGOSITY_CD', 'WTD_RUG', 'MEAN_RUG', 'MAPGRID_NR', 'SUB_REGION_NAME', 'SUB_REGION_NAME_DESCRIPTION', 'SUB_REGION_NR', 'ZONE_NAME', 'ZONE_NR', 'MPA_NAME', 'MPA_NR', 'ADMIN', 'PROT', 'N', 'JUV', 'accession_url'] 

df = df.drop(columns = dropped_cols, axis=1)

df.to_csv('CRCP_Coral_Demographic_USVI_Cleaned.csv')
# Out:
# /var/folders/hl/s0xx7r0j66nf3d472gxnx2880000gn/T/ipykernel_79208/3480668254.py:5: DtypeWarning: Columns (1,2,17,31,32,33,38,39,40,41,42,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(par_dir_abs + "/data/raw/CORIS_DATA/ATLANTIC/USVI/CRCP_Coral_Demographic_Survey_USVI_a96f_e9c4_c0c5.csv")
#                         time       latitude     longitude    HABITAT_TYPE  \
# 0                        UTC  degrees_north  degrees_east             NaN
# 1       2023-06-10T00:00:00Z       17.69446     -64.67509        Pavement
# 2       2023-06-10T00:00:00Z       17.69446     -64.67509        Pavement
# 3       2023-06-10T00:00:00Z       17.69446     -64.67509        Pavement
# 4       2023-06-10T00:00:00Z       17.69446     -64.67509        Pavement
# ...                      ...            ...           ...             ...
# 175501  2023-08-18T00:00:00Z       18.36528     -64.77411  Aggregate reef
# 175502  2023-08-18T00:00:00Z       18.36528     -64.77411  Aggregate reef
# 175503  2023-08-18T00:00:00Z       18.36528     -64.77411  Aggregate reef
# 175504  2023-08-18T00:00:00Z       18.36528     -64.77411  Aggregate reef
# 175505  2023-08-18T00:00:00Z       18.36528     -64.77411  Aggregate reef
#
#              STRAT_Description    Administration_Description DEPTH_STRAT  \
# 0                          NaN                           NaN         NaN
# 1             Pavement shallow         All non-managed areas        SHLW
# 2             Pavement shallow         All non-managed areas        SHLW
# 3             Pavement shallow         All non-managed areas        SHLW
# 4             Pavement shallow         All non-managed areas        SHLW
# ...                        ...                           ...         ...
# 175501  Aggregate reef shallow  Virgin Islands National Park        SHLW
# 175502  Aggregate reef shallow  Virgin Islands National Park        SHLW
# 175503  Aggregate reef shallow  Virgin Islands National Park        SHLW
# 175504  Aggregate reef shallow  Virgin Islands National Park        SHLW
# 175505  Aggregate reef shallow  Virgin Islands National Park        SHLW
#
#        DEPTH_STRAT_DESCRIPTION MIN_DEPTH MAX_DEPTH METERS_COMPLETED  \
# 0                          NaN         m         m                m
# 1           shallow (0-11.9 m)       NaN       NaN             10.0
# 2           shallow (0-11.9 m)       NaN       NaN             10.0
# 3           shallow (0-11.9 m)       NaN       NaN             10.0
# 4           shallow (0-11.9 m)       NaN       NaN             10.0
# ...                        ...       ...       ...              ...
# 175501      shallow (0-11.9 m)     9.144    10.668             10.0
# 175502      shallow (0-11.9 m)     9.144    10.668             10.0
# 175503      shallow (0-11.9 m)     9.144    10.668             10.0
# 175504      shallow (0-11.9 m)     9.144    10.668             10.0
# 175505      shallow (0-11.9 m)     9.144    10.668             10.0
#
#        SPECIES_CD               SPECIES_NAME MAX_DIAMETER PERP_DIAMETER  \
# 0             NaN                        NaN           cm            cm
# 1        AGA GRAH          Agaricia grahamae          NaN           NaN
# 2        AGA HUMI           Agaricia humilis          NaN           NaN
# 3        AGA LAMA          Agaricia lamarcki          NaN           NaN
# 4        AGA SPE.               Agaricia spp          NaN           NaN
# ...           ...                        ...          ...           ...
# 175501   SID SIDE        Siderastrea siderea          5.0           3.0
# 175502   SID SIDE        Siderastrea siderea          5.0           2.0
# 175503   SID SPE.            Siderastrea spp          NaN           NaN
# 175504   SOL BOUR       Solenastrea bournoni          NaN           NaN
# 175505   STE INTE  Stephanocoenia intersepta          9.0           7.0
#
#        HEIGHT OLD_MORT RECENT_MORT BLEACH_CONDITION DISEASE
# 0          cm  percent     percent              NaN     NaN
# 1         NaN      NaN         NaN              NaN     NaN
# 2         NaN      NaN         NaN              NaN     NaN
# 3         NaN      NaN         NaN              NaN     NaN
# 4         NaN      NaN         NaN              NaN     NaN
# ...       ...      ...         ...              ...     ...
# 175501    1.0      0.0         0.0                N       A
# 175502    1.0      0.0         0.0                N       A
# 175503    NaN      NaN         NaN              NaN     NaN
# 175504    NaN      NaN         NaN              NaN     NaN
# 175505    2.0     10.0         0.0                N       A
#
# [175506 rows x 20 columns]
