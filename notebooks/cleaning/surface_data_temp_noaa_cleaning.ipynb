# %%
import os
import pandas as pd

# %%
curr_dir = os.getcwd()
parent_dir = os.path.join(curr_dir, "..", "..")
parent_dir_abs = os.path.abspath(parent_dir)

df = pd.read_csv(parent_dir_abs + "/data/raw/NOAA/SurfaceDataTemp.csv")

df = df.rename(columns={'sst': 'Sea Surface Temperature in Celsius'})

df.to_csv('Surface_Data_Temperature_Cleaned.csv')
# Out:
# /var/folders/hl/s0xx7r0j66nf3d472gxnx2880000gn/T/ipykernel_33628/1790424489.py:5: DtypeWarning: Columns (1,2,3,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(parent_dir_abs + "/data/raw/NOAA/SurfaceDataTemp.csv")
