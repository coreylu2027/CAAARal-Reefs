# %%
import pandas as pd

# %%
# Define the filter criteria
target_year = 2000
chunk_size = 50000  # Adjust based on your available memory

# Create an empty list to store filtered chunks
filtered_chunks = []

cols_to_keep = ['SID', 'SEASON', 'NAME', 'ISO_TIME', 'LAT', 'LON', 'WMO_WIND', 'WMO_PRES', 'USA_WIND', 'USA_PRES', 'USA_SSHS', 'STORM_SPEED', 'STORM_DIR', 'DIST2LAND', 'LANDFALL', 'TRACK_TYPE']

# Read and filter in one pass using chunks
for chunk in pd.read_csv(
        "climateDataibtrac.csv",
    na_values=["nd", "ND", "Nd"],
    low_memory=False,
    chunksize=chunk_size,
    usecols=cols_to_keep
):
    # Convert SEASON to numeric within the chunk
    chunk['SEASON'] = pd.to_numeric(chunk['SEASON'], errors='coerce')

    # Filter the chunk
    filtered_chunk = chunk[chunk['SEASON'] >= target_year]

    # Append the result
    filtered_chunks.append(filtered_chunk)

# Combine filtered chunks into a single DataFrame
df = pd.concat(filtered_chunks, ignore_index=True)

df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 11
#       8 cols_to_keep = ['SID', 'SEASON', 'NAME', 'ISO_TIME', 'LAT', 'LON', 'WMO_WIND', 'WMO_PRES', 'USA_WIND', 'USA_PRES', 'USA_SSHS', 'STORM_SPEED', 'STORM_DIR', 'DIST2LAND', 'LANDFALL', 'TRACK_TYPE']
#      10 # Read and filter in one pass using chunks
# ---> 11 for chunk in pd.read_csv(
#      12         "climateDataibtrac.csv",
#      13     na_values=["nd", "ND", "Nd"],
#      14     low_memory=False,
#      15     chunksize=chunk_size,
#      16     usecols=cols_to_keep
#      17 ):
#      18     # Convert SEASON to numeric within the chunk
#      19     chunk['SEASON'] = pd.to_numeric(chunk['SEASON'], errors='coerce')
#      21     # Filter the chunk
#
# File ~/Documents/CAAAral_Reefs/venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Documents/CAAAral_Reefs/venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/Documents/CAAAral_Reefs/venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/Documents/CAAAral_Reefs/venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/Documents/CAAAral_Reefs/venv/lib/python3.11/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'climateDataibtrac.csv'

# %%
df.to_csv("../../data/processed/IBTrACS/filtered_cyclone.csv", index=False)
