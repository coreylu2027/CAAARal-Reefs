# %%
import pandas as pd
import numpy as np
import os

# %%
curr_dir = os.getcwd()

df = pd.read_csv(curr_dir + "/CRCP_Benthic_Cover_Florida_7018_0ee5_9488.csv")

pd.set_option('display.max_columns', None)

dropped_cols = ["REGION", "MONTH", "DAY", "Date_UTC", "STATION_NR", "STRAT", "RUGOSITY_CD", "ADMIN", "DEPTH_STRAT", "accession_url"]

df = df.drop(columns=dropped_cols, axis=1)

df
# Out:
#                        time       latitude     longitude  PRIMARY_SAMPLE_UNIT  \
# 0                       UTC  degrees_north  degrees_east                  NaN
# 1      2016-06-22T00:00:00Z       24.46499      -81.9823               1702.0
# 2      2016-06-22T00:00:00Z       24.46499      -81.9823               1702.0
# 3      2016-06-22T00:00:00Z       24.46499      -81.9823               1702.0
# 4      2016-06-22T00:00:00Z       24.46499      -81.9823               1702.0
# ...                     ...            ...           ...                  ...
# 13597  2022-12-16T00:00:00Z       24.61591     -81.39097               9208.0
# 13598  2022-12-16T00:00:00Z       24.61591     -81.39097               9208.0
# 13599  2022-12-16T00:00:00Z       24.61591     -81.39097               9208.0
# 13600  2022-12-16T00:00:00Z       24.61591     -81.39097               9208.0
# 13601  2022-12-16T00:00:00Z       24.61591     -81.39097               9208.0
#
#        STATION_NR    YEAR HABITAT_CD  \
# 0             NaN     NaN        NaN
# 1             1.0  2016.0    CONT_LR
# 2             1.0  2016.0    CONT_LR
# 3             1.0  2016.0    CONT_LR
# 4             1.0  2016.0    CONT_LR
# ...           ...     ...        ...
# 13597         1.0  2022.0    ISOL_MR
# 13598         1.0  2022.0    ISOL_MR
# 13599         1.0  2022.0    ISOL_MR
# 13600         1.0  2022.0    ISOL_MR
# 13601         1.0  2022.0    ISOL_MR
#
#                                             HABITAT_TYPE STRAT  \
# 0                                                    NaN   NaN
# 1      Contiguous reef - non-spur-groove - low vertic...  MCPR
# 2      Contiguous reef - non-spur-groove - low vertic...  MCPR
# 3      Contiguous reef - non-spur-groove - low vertic...  MCPR
# 4      Contiguous reef - non-spur-groove - low vertic...  MCPR
# ...                                                  ...   ...
# 13597  Isolated - patchy reef structures - moderate v...  CS01
# 13598  Isolated - patchy reef structures - moderate v...  CS01
# 13599  Isolated - patchy reef structures - moderate v...  CS01
# 13600  Isolated - patchy reef structures - moderate v...  CS01
# 13601  Isolated - patchy reef structures - moderate v...  CS01
#
#                   Description  RUGOSITY_CD   WTD_RUG  MAPGRID_NR  \
# 0                         NaN          NaN       NaN         NaN
# 1      Mid Channel Patch Reef          NaN  0.296667    888235.0
# 2      Mid Channel Patch Reef          NaN  0.296667    888235.0
# 3      Mid Channel Patch Reef          NaN  0.296667    888235.0
# 4      Mid Channel Patch Reef          NaN  0.296667    888235.0
# ...                       ...          ...       ...         ...
# 13597                     NaN          NaN       NaN   2463949.0
# 13598                     NaN          NaN       NaN   2463949.0
# 13599                     NaN          NaN       NaN   2463949.0
# 13600                     NaN          NaN       NaN   2463949.0
# 13601                     NaN          NaN       NaN   2463949.0
#
#       SUB_REGION_NAME  SUB_REGION_NR    ZONE_NAME  ZONE_NR         MPA_NAME  \
# 0                 NaN            NaN          NaN      NaN              NaN
# 1          Lower Keys            8.0  Mid Channel      2.0      Unprotected
# 2          Lower Keys            8.0  Mid Channel      2.0      Unprotected
# 3          Lower Keys            8.0  Mid Channel      2.0      Unprotected
# 4          Lower Keys            8.0  Mid Channel      2.0      Unprotected
# ...               ...            ...          ...      ...              ...
# 13597      Lower Keys            8.0      Inshore      1.0  Newfound_Harbor
# 13598      Lower Keys            8.0      Inshore      1.0  Newfound_Harbor
# 13599      Lower Keys            8.0      Inshore      1.0  Newfound_Harbor
# 13600      Lower Keys            8.0      Inshore      1.0  Newfound_Harbor
# 13601      Lower Keys            8.0      Inshore      1.0  Newfound_Harbor
#
#        MPA_NR  ADMIN  PROT DEPTH_STRAT    MIN_DEPTH    MAX_DEPTH  \
# 0         NaN    NaN   NaN         NaN            m            m
# 1         0.0    NaN   0.0         NaN  7.010399776  7.315199766
# 2         0.0    NaN   0.0         NaN  7.010399776  7.315199766
# 3         0.0    NaN   0.0         NaN  7.010399776  7.315199766
# 4         0.0    NaN   0.0         NaN  7.010399776  7.315199766
# ...       ...    ...   ...         ...          ...          ...
# 13597    18.0    NaN   2.0         CD0  2.438399922  2.438399922
# 13598    18.0    NaN   2.0         CD0  2.438399922  2.438399922
# 13599    18.0    NaN   2.0         CD0  2.438399922  2.438399922
# 13600    18.0    NaN   2.0         CD0  2.438399922  2.438399922
# 13601    18.0    NaN   2.0         CD0  2.438399922  2.438399922
#
#       METERS_COMPLETED COVER_CAT_CD               COVER_CAT_NAME HARDBOTTOM_P  \
# 0                    m          NaN                          NaN      percent
# 1                   15     EUS FAST          Eusmilia fastigiata            1
# 2                   15     GOR ENCR         Encrusting gorgonian            2
# 3                   15     GOR GORG                   Gorgonians           13
# 4                   15     MEA MEAN         Meandrina meandrites            1
# ...                ...          ...                          ...          ...
# 13597               15     DIC SPE.                 Dictyota spp            4
# 13598               15     HAL SPE.                 Halimeda spp           43
# 13599               15     ORB ANNU          Orbicella annularis            1
# 13600               15     RHO CRUS          Rhodophyta cru. spp            3
# 13601               15     TUR FREE  Turf Algae Free of Sediment           41
#
#       SOFTBOTTOM_P RUBBLE_P                            accession_url
# 0          percent  percent                                      NaN
# 1                0        0  https://accession.nodc.noaa.gov/0169401
# 2                0        0  https://accession.nodc.noaa.gov/0169401
# 3                0        0  https://accession.nodc.noaa.gov/0169401
# 4                0        0  https://accession.nodc.noaa.gov/0169401
# ...            ...      ...                                      ...
# 13597            0        0  https://accession.nodc.noaa.gov/0282195
# 13598            0        0  https://accession.nodc.noaa.gov/0282195
# 13599            0        0  https://accession.nodc.noaa.gov/0282195
# 13600            0        0  https://accession.nodc.noaa.gov/0282195
# 13601            0        0  https://accession.nodc.noaa.gov/0282195
#
# [13602 rows x 31 columns]
