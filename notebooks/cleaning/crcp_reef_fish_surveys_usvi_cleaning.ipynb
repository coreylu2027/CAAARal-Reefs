# %%
import pandas as pd
import os

# %%
curr_dir = os.getcwd()
par_dir = os.path.join(curr_dir, "..", "..")
par_dir_abs = os.path.abspath(par_dir)

df = pd.read_csv(par_dir_abs + "/data/raw/CORIS_DATA/ATLANTIC/USVI/CRCP_Reef_Fish_Surveys_USVI_42b0_c669_8d15.csv")

pd.set_option('display.max_columns', None)

dropped_cols = ['REGION', 'REGION_DESCRIPTION', 'PRIMARY_SAMPLE_UNIT', 'STATION_NR', 'YEAR', 'MONTH', 'DAY', 'Date_UTC', 'HABITAT_CD', 'STRAT', 'MAPGRID_NR', 'SUB_REGION_NAME', 'SUB_REGION_NAME_DESCRIPTION', 'ADMIN', 'PROT', 'accession_url', 'DEPTH']

df = df.drop(columns = dropped_cols, axis=1)

df.to_csv('CRCP_Fish_Survey_USVI_Cleaned.csv')
# Out:
# /var/folders/hl/s0xx7r0j66nf3d472gxnx2880000gn/T/ipykernel_79473/3807427896.py:5: DtypeWarning: Columns (1,2,9,10,24,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(par_dir_abs + "/data/raw/CORIS_DATA/ATLANTIC/USVI/CRCP_Reef_Fish_Surveys_USVI_42b0_c669_8d15.csv")
#                         time       latitude     longitude DEPTH  \
# 0                        UTC  degrees_north  degrees_east     m
# 1       2021-08-05T00:00:00Z       18.19912      -64.7334   NaN
# 2       2021-08-05T00:00:00Z       18.19912      -64.7334   NaN
# 3       2021-08-05T00:00:00Z       18.19912      -64.7334   NaN
# 4       2021-08-05T00:00:00Z       18.19912      -64.7334   NaN
# ...                      ...            ...           ...   ...
# 913136  2021-08-05T00:00:00Z       18.19912      -64.7334   NaN
# 913137  2021-08-05T00:00:00Z       18.19912      -64.7334   NaN
# 913138  2021-08-05T00:00:00Z       18.19912      -64.7334   NaN
# ...
