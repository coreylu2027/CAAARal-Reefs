# %%
import pandas as pd
import numpy as np
import os

# %%
curr_dir = os.getcwd()

df = pd.read_csv(curr_dir + "/CRCP_Coral_Demographic_Survey_Florida_4525_37fd_301a.csv")

pd.set_option('display.max_columns', None)

dropped_cols = ["REGION", "STATION_NR", "MONTH", "DAY", "Date_UTC", "ZONE_NAME", "ZONE_NR", "MPA_NAME", "MPA_NR", "PROT", "ADMIN", "DEPTH_STRAT", "accession_url", "N", "JUV", "OLD_MORT", "RECENT_MORT"]

df = df.drop(columns=dropped_cols, axis=1)

df

df.to_csv("Coral_Demographics_Florida_Cleaned.csv")
# Out:
# /var/folders/hl/s0xx7r0j66nf3d472gxnx2880000gn/T/ipykernel_58952/2984627142.py:3: DtypeWarning: Columns (1,2,25,26,27,28,33,34,35,36,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(curr_dir + "/CRCP_Coral_Demographic_Survey_Florida_4525_37fd_301a.csv")
